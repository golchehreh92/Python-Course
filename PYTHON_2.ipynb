# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # SERIES

# %%
lable=["a","b","c"]
data=[10,20,30]
arr=np.array(data)
d={"a":10,"b":20,"c":30}

# %%
pd.Series(data,lable)    #conerting two lists to series
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr,lable)   #converting array to series
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %%
pd.Series(d)            #conerting dic to series
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
seri1=pd.Series([17,18,12,11],["math","phsics","art","sport"])
seri1
# Out:
# math      17
# phsics    18
# art       12
# sport     11
# dtype: int64

# %%
seri["art"]
# Out:
# 12

# %%
seri2=pd.Series([15,16,16,14],["math","phsics","art","sport"])
seri2
# Out:
# math      15
# phsics    16
# art       16
# sport     14
# dtype: int64

# %%
seri1+seri2        #we can sum two series
# Out:
# math      32
# phsics    34
# art       28
# sport     25
# dtype: int64

# %% [markdown]
# # DataFrames

# %%
np.random.randn(4,5)
# Out:
# array([[ 1.75269606, -0.58241655,  0.74640582,  0.12194009,  0.85198566],
#        [ 0.05513243, -1.00889886, -0.72512689,  0.1517126 , -0.81231608],
#        [ 2.50608361, -0.30724461,  0.41055733,  0.90457221,  1.21270011],
#        [ 0.17431053,  0.35326361,  0.37427009,  0.13465258, -1.1815208 ]])

# %%
df=pd.DataFrame(np.random.randn(4,5),["a","b","c","d"],["s1","s2","s3","s4","s5"])
#use dataframe for having an table
df
# Out:
#          s1        s2        s3        s4        s5
# a -1.876345 -0.815029 -1.941473 -2.430104 -0.641854
# b  0.826486 -0.091219  0.931666  0.893492 -0.823814
# c -0.163189 -2.056758  3.244824 -0.786788 -1.294675
# d -0.936090 -0.072483  1.056839  0.319354 -0.147814

# %%
df["s3"]["a"]
# Out:
# -1.9414729977176397

# %%
df[["s1","s2"]]
# Out:
#          s1        s2
# a -1.876345 -0.815029
# b  0.826486 -0.091219
# c -0.163189 -2.056758
# d -0.936090 -0.072483

# %%
df["s6"]=np.random.randn(4)    # inserting new column
df
# Out:
#          s1        s2        s3        s4        s5        s6
# a -1.876345 -0.815029 -1.941473 -2.430104 -0.641854 -0.665269
# b  0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628
# c -0.163189 -2.056758  3.244824 -0.786788 -1.294675 -0.342768
# d -0.936090 -0.072483  1.056839  0.319354 -0.147814 -0.227949

# %%
df["sum"]=df["s1"]+df["s2"]+df["s3"]+df["s4"]+df["s5"]+df["s6"]

# %%
df
# Out:
#          s1        s2        s3        s4        s5        s6
# a -1.876345 -0.815029 -1.941473 -2.430104 -0.641854 -0.665269
# b  0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628
# c -0.163189 -2.056758  3.244824 -0.786788 -1.294675 -0.342768
# d -0.936090 -0.072483  1.056839  0.319354 -0.147814 -0.227949

# %%
df["s1+s2"]=df["s1"]+df["s2"]

# %%
df
# Out:
#          s1        s2        s3        s4        s5        s6     s1+s2
# a -1.876345 -0.815029 -1.941473 -2.430104 -0.641854 -0.665269 -2.691375
# b  0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628  0.735267
# c -0.163189 -2.056758  3.244824 -0.786788 -1.294675 -0.342768 -2.219947
# d -0.936090 -0.072483  1.056839  0.319354 -0.147814 -0.227949 -1.008573

# %%
df.drop("s1+s2",axis=1)  
#for eliminating a coloumn we should use drop and first we enter the name and then the axis=1 which means that is a coloumn
# Out:
#          s1        s2        s3        s4        s5        s6
# a -1.876345 -0.815029 -1.941473 -2.430104 -0.641854 -0.665269
# b  0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628
# c -0.163189 -2.056758  3.244824 -0.786788 -1.294675 -0.342768
# d -0.936090 -0.072483  1.056839  0.319354 -0.147814 -0.227949

# %%
df  #again e have the s1+s2 so for eliminating compeletly we have two way....first df=df.drop sec:df.drop(inplace:true)
# Out:
#          s1        s2        s3        s4        s5        s6     s1+s2
# a -1.876345 -0.815029 -1.941473 -2.430104 -0.641854 -0.665269 -2.691375
# b  0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628  0.735267
# c -0.163189 -2.056758  3.244824 -0.786788 -1.294675 -0.342768 -2.219947
# d -0.936090 -0.072483  1.056839  0.319354 -0.147814 -0.227949 -1.008573

# %%
df["s3+s4"]=df["s3"]+df["s4"]
df
# Out:
#          s1        s2        s3        s4        s5        s6     s1+s2  \
# a -1.876345 -0.815029 -1.941473 -2.430104 -0.641854 -0.665269 -2.691375
# b  0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628  0.735267
# c -0.163189 -2.056758  3.244824 -0.786788 -1.294675 -0.342768 -2.219947
# d -0.936090 -0.072483  1.056839  0.319354 -0.147814 -0.227949 -1.008573
#
#       s3+s4
# a -4.371577
# b  1.825158
# c  2.458036
# d  1.376192

# %%
df=df.drop("s1+s2",axis=1)
df
# Out:
#          s1        s2        s3        s4        s5        s6     s3+s4
# a -1.876345 -0.815029 -1.941473 -2.430104 -0.641854 -0.665269 -4.371577
# b  0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628  1.825158
# c -0.163189 -2.056758  3.244824 -0.786788 -1.294675 -0.342768  2.458036
# d -0.936090 -0.072483  1.056839  0.319354 -0.147814 -0.227949  1.376192

# %%
df
# Out:
#          s1        s2        s3        s4        s5        s6     s3+s4
# a -1.876345 -0.815029 -1.941473 -2.430104 -0.641854 -0.665269 -4.371577
# b  0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628  1.825158
# c -0.163189 -2.056758  3.244824 -0.786788 -1.294675 -0.342768  2.458036
# d -0.936090 -0.072483  1.056839  0.319354 -0.147814 -0.227949  1.376192

# %%
df
# Out:
#          s1        s2        s3        s4        s5        s6     s3+s4
# a -1.876345 -0.815029 -1.941473 -2.430104 -0.641854 -0.665269 -4.371577
# b  0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628  1.825158
# c -0.163189 -2.056758  3.244824 -0.786788 -1.294675 -0.342768  2.458036
# d -0.936090 -0.072483  1.056839  0.319354 -0.147814 -0.227949  1.376192

# %%
df.shape   #vase shape nabayad () bzarim vagarna error mde
# Out:
# (4, 7)

# %% [markdown]
# # iloc and loc

# %% [markdown]
# we use loc for calling the rows

# %%
df.loc["b"]
# Out:
# s1   -0.718533
# s2    0.033656
# s3   -0.128133
# s4    1.358138
# s5   -2.985593
# s6    0.441096
# Name: b, dtype: float64

# %%
df["b"]    #if we say just "b" ithout loc we will get an error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'b'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-a468a268bbcd> in <module>()
# ----> 1 df["b"]
#
# ...

# %%
df.iloc[0]
# Out:
# s1    1.226393
# s2    2.109406
# s3    1.034529
# s4    0.440990
# s5    1.801526
# s6    1.512431
# Name: a, dtype: float64

# %%
df.loc["a"]
# Out:
# s1    1.226393
# s2    2.109406
# s3    1.034529
# s4    0.440990
# s5    1.801526
# s6    1.512431
# Name: a, dtype: float64

# %%
df.loc["a","s1"]
# Out:
# 1.2263930545294772

# %%
df["s1"]["a"]
# Out:
# 1.2263930545294772

# %%
df.loc[["a","b"],["s1","s2"]]
# Out:
#          s1        s2
# a  1.226393  2.109406
# b -0.718533  0.033656

# %% [markdown]
# # conditions in dataframes

# %%
j= df>0

# %%
j
# Out:
#       s1     s2     s3    s4     s5     s6
# a   True   True   True  True   True   True
# b  False   True  False  True  False   True
# c  False  False   True  True   True  False
# d   True   True   True  True   True  False

# %%
df[j]
# Out:
#          s1        s2        s3        s4        s5        s6
# a  1.226393  2.109406  1.034529  0.440990  1.801526  1.512431
# b       NaN  0.033656       NaN  1.358138       NaN  0.441096
# c       NaN       NaN  1.910341  2.641652  0.337832       NaN
# d  0.690219  0.826010  0.301494  1.610348  0.545297       NaN

# %%
df[df>2]
# Out:
#    s1        s2  s3        s4  s5  s6
# a NaN  2.109406 NaN       NaN NaN NaN
# b NaN       NaN NaN       NaN NaN NaN
# c NaN       NaN NaN  2.641652 NaN NaN
# d NaN       NaN NaN       NaN NaN NaN

# %%
df["s2"]>0
# Out:
# a     True
# b     True
# c    False
# d     True
# Name: s2, dtype: bool

# %%
df[df["s2"]>0]      #tuye s2 harchi manfi hazf mshe pas c kolan hazf
# Out:
#          s1        s2        s3        s4        s5        s6
# a  1.226393  2.109406  1.034529  0.440990  1.801526  1.512431
# b -0.718533  0.033656 -0.128133  1.358138 -2.985593  0.441096
# d  0.690219  0.826010  0.301494  1.610348  0.545297 -0.330454

# %% [markdown]
# # Filtering

# %%
df
# Out:
#          s1        s2        s3        s4        s5        s6     s3+s4
# a -1.876345 -0.815029 -1.941473 -2.430104 -0.641854 -0.665269 -4.371577
# b  0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628  1.825158
# c -0.163189 -2.056758  3.244824 -0.786788 -1.294675 -0.342768  2.458036
# d -0.936090 -0.072483  1.056839  0.319354 -0.147814 -0.227949  1.376192

# %%
df[df["s3"]>0]
# Out:
#          s1        s2        s3        s4        s5        s6     s3+s4
# b  0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628  1.825158
# c -0.163189 -2.056758  3.244824 -0.786788 -1.294675 -0.342768  2.458036
# d -0.936090 -0.072483  1.056839  0.319354 -0.147814 -0.227949  1.376192

# %%
df[(df["s3"]>0) & (df["s1"]>0)]
# Out:
#          s1        s2        s3        s4        s5        s6     s3+s4
# b  0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628  1.825158

# %%
df[(df["s3"]>0) | (df["s1"]>0)]    # hatman tu parantez va hatman | k yani or
# Out:
#          s1        s2        s3        s4        s5        s6     s3+s4
# b  0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628  1.825158
# c -0.163189 -2.056758  3.244824 -0.786788 -1.294675 -0.342768  2.458036
# d -0.936090 -0.072483  1.056839  0.319354 -0.147814 -0.227949  1.376192

# %% [markdown]
# # Resetting Index

# %%
df.reset_index()
# Out:
#   index        s1        s2        s3        s4        s5        s6     s3+s4
# 0     a -1.876345 -0.815029 -1.941473 -2.430104 -0.641854 -0.665269 -4.371577
# 1     b  0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628  1.825158
# 2     c -0.163189 -2.056758  3.244824 -0.786788 -1.294675 -0.342768  2.458036
# 3     d -0.936090 -0.072483  1.056839  0.319354 -0.147814 -0.227949  1.376192

# %%
country="usa iran japan  india".split()

# %%
country
# Out:
# ['usa', 'iran', 'japan', 'india']

# %%
df["country"]= country
df
# Out:
#          s1        s2        s3        s4        s5        s6     s3+s4  \
# a -1.876345 -0.815029 -1.941473 -2.430104 -0.641854 -0.665269 -4.371577
# b  0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628  1.825158
# c -0.163189 -2.056758  3.244824 -0.786788 -1.294675 -0.342768  2.458036
# d -0.936090 -0.072483  1.056839  0.319354 -0.147814 -0.227949  1.376192
#
#   country
# a     usa
# b    iran
# c   japan
# d   india

# %% [markdown]
# # SET INDEX

# %%
df=df.set_index("country")

# %%
df
# Out:
#                s1        s2        s3        s4        s5        s6     s3+s4
# country
# usa     -1.876345 -0.815029 -1.941473 -2.430104 -0.641854 -0.665269 -4.371577
# iran     0.826486 -0.091219  0.931666  0.893492 -0.823814  0.638628  1.825158
# japan   -0.163189 -2.056758  3.244824 -0.786788 -1.294675 -0.342768  2.458036
# india   -0.936090 -0.072483  1.056839  0.319354 -0.147814 -0.227949  1.376192

# %% [markdown]
# # INDEX LEVELING

# %%
outside="G1 G1 G1 G2 G2 G2".split()
outside
# Out:
# ['G1', 'G1', 'G1', 'G2', 'G2', 'G2']

# %%
inside=[1,2,3,1,2,3]

# %%
h_index=list(zip(outside,inside))

# %%
h_index
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
h_index= pd.MultiIndex.from_tuples(h_index)

# %%
h_index
# Out:
# MultiIndex(levels=[['G1', 'G2'], [1, 2, 3]],
#            labels=[[0, 0, 0, 1, 1, 1], [0, 1, 2, 0, 1, 2]])

# %%
data=pd.DataFrame(np.random.randn(6,2),h_index,["a","b"])
data
# Out:
#              a         b
# G1 1 -1.101396 -1.713207
#    2  0.017500  0.858790
#    3 -0.893438  0.215154
# G2 1  1.153804 -1.757403
#    2  1.646532  0.714498
#    3  0.844913  0.563847

# %%
data.loc["G1",'a']
# Out:
# 1   -1.101396
# 2    0.017500
# 3   -0.893438
# Name: a, dtype: float64

# %% [markdown]
# # DateTime

# %%
db=pd.read_csv(r"E:\python\dataset\seesion2\DB.csv")

# %%
db
# Out:
#       Melbourne  Cairo  Singapore  London  New Dehli  Berlin  Montreal  \
# 0          23.5   11.1       24.7     5.4       15.2     6.6      -5.9
# 1          22.5   10.0       24.4     5.8       15.2     6.8      -8.6
# 2          21.5   10.0       24.2     5.9       15.2     7.0     -10.7
# 3          20.8   10.5       24.1     6.5       15.2     7.2     -12.0
# 4          20.1   10.9       24.1     6.9       15.0     7.3     -12.8
# 5          19.4   11.4       24.0     7.0       15.0     7.4     -13.5
# 6          18.9   11.9       24.2     7.4       14.2     7.0     -13.3
# 7          18.4   12.3       24.3     7.9       14.0     7.5     -14.4
# 8          17.9   12.8       25.5     8.5       13.5     7.7     -13.9
# 9          22.5   14.5       26.8     9.3       13.5     8.0     -12.8
# 10         16.7   16.1       28.0    10.8       13.4     7.6     -11.7
# 11         17.4   17.8       26.8    12.3       13.0     8.3     -10.6
# ...

# %%
db
# Out:
#       Melbourne  Cairo  Singapore  London  New Dehli  Berlin  Montreal  \
# 0          23.5   11.1       24.7     5.4       15.2     6.6      -5.9
# 1          22.5   10.0       24.4     5.8       15.2     6.8      -8.6
# 2          21.5   10.0       24.2     5.9       15.2     7.0     -10.7
# 3          20.8   10.5       24.1     6.5       15.2     7.2     -12.0
# 4          20.1   10.9       24.1     6.9       15.0     7.3     -12.8
# 5          19.4   11.4       24.0     7.0       15.0     7.4     -13.5
# 6          18.9   11.9       24.2     7.4       14.2     7.0     -13.3
# 7          18.4   12.3       24.3     7.9       14.0     7.5     -14.4
# 8          17.9   12.8       25.5     8.5       13.5     7.7     -13.9
# 9          22.5   14.5       26.8     9.3       13.5     8.0     -12.8
# 10         16.7   16.1       28.0    10.8       13.4     7.6     -11.7
# 11         17.4   17.8       26.8    12.3       13.0     8.3     -10.6
# ...

# %%
db.head()    # 5 ta radif aval ro khoruji mde
# Out:
#    Melbourne  Cairo  Singapore  London  New Dehli  Berlin  Montreal  Tehran  \
# 0       23.5   11.1       24.7     5.4       15.2     6.6      -5.9     0.7
# 1       22.5   10.0       24.4     5.8       15.2     6.8      -8.6     0.7
# 2       21.5   10.0       24.2     5.9       15.2     7.0     -10.7     0.7
# 3       20.8   10.5       24.1     6.5       15.2     7.2     -12.0     0.4
# 4       20.1   10.9       24.1     6.9       15.0     7.3     -12.8    -0.4
#
#    Santiago
# 0      15.2
# 1      14.8
# 2      14.4
# 3      14.0
# 4      13.6

# %%
db.head(8)
# Out:
#    Melbourne  Cairo  Singapore  London  New Dehli  Berlin  Montreal  Tehran  \
# 0       23.5   11.1       24.7     5.4       15.2     6.6      -5.9     0.7
# 1       22.5   10.0       24.4     5.8       15.2     6.8      -8.6     0.7
# 2       21.5   10.0       24.2     5.9       15.2     7.0     -10.7     0.7
# 3       20.8   10.5       24.1     6.5       15.2     7.2     -12.0     0.4
# 4       20.1   10.9       24.1     6.9       15.0     7.3     -12.8    -0.4
# 5       19.4   11.4       24.0     7.0       15.0     7.4     -13.5    -0.6
# 6       18.9   11.9       24.2     7.4       14.2     7.0     -13.3    -0.2
# 7       18.4   12.3       24.3     7.9       14.0     7.5     -14.4     1.5
#
#    Santiago
# 0      15.2
# 1      14.8
# 2      14.4
# 3      14.0
# 4      13.6
# 5      15.0
# 6      16.5
# 7      17.9

# %%
db.tail()
# Out:
#       Melbourne  Cairo  Singapore  London  New Dehli  Berlin  Montreal  \
# 8755       30.6   16.0       26.6     7.6       13.7     5.6       2.1
# 8756       28.0   15.0       26.3     7.4       12.2     5.7       1.8
# 8757       25.7   14.0       25.9     7.1       10.8     5.8       1.0
# 8758       23.4   14.0       25.5     6.9        9.3     6.0      -0.6
# 8759       21.1   12.0       25.1     7.1        7.9     6.3      -3.0
#
#       Tehran  Santiago
# 8755     3.1      21.3
# 8756     2.7      19.9
# 8757     2.6      18.5
# 8758     2.2      17.1
# 8759     2.0      16.5

# %%
db.max()
# Out:
# Melbourne    38.3
# Cairo        40.0
# Singapore    33.8
# London       31.0
# New Dehli    44.0
# Berlin       32.8
# Montreal     31.7
# Tehran       40.0
# Santiago     35.0
# dtype: float64

# %%
step=pd.date_range("2021-01-01", periods=90, freq="1D")     #period is the amount of days in 3 month for instance
step
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10', '2021-01-11', '2021-01-12',
#                '2021-01-13', '2021-01-14', '2021-01-15', '2021-01-16',
#                '2021-01-17', '2021-01-18', '2021-01-19', '2021-01-20',
#                '2021-01-21', '2021-01-22', '2021-01-23', '2021-01-24',
#                '2021-01-25', '2021-01-26', '2021-01-27', '2021-01-28',
#                '2021-01-29', '2021-01-30', '2021-01-31', '2021-02-01',
#                '2021-02-02', '2021-02-03', '2021-02-04', '2021-02-05',
#                '2021-02-06', '2021-02-07', '2021-02-08', '2021-02-09',
#                '2021-02-10', '2021-02-11', '2021-02-12', '2021-02-13',
#                '2021-02-14', '2021-02-15', '2021-02-16', '2021-02-17',
#                '2021-02-18', '2021-02-19', '2021-02-20', '2021-02-21',
# ...

# %%
time_step=pd.date_range("2021-01-01", periods=8760, freq="1H" )
time_step
# Out:
# DatetimeIndex(['2021-01-01 00:00:00', '2021-01-01 01:00:00',
#                '2021-01-01 02:00:00', '2021-01-01 03:00:00',
#                '2021-01-01 04:00:00', '2021-01-01 05:00:00',
#                '2021-01-01 06:00:00', '2021-01-01 07:00:00',
#                '2021-01-01 08:00:00', '2021-01-01 09:00:00',
#                ...
#                '2021-12-31 14:00:00', '2021-12-31 15:00:00',
#                '2021-12-31 16:00:00', '2021-12-31 17:00:00',
#                '2021-12-31 18:00:00', '2021-12-31 19:00:00',
#                '2021-12-31 20:00:00', '2021-12-31 21:00:00',
#                '2021-12-31 22:00:00', '2021-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=8760, freq='H')

# %%
db["Date"]=time_step
db
# Out:
#       Melbourne  Cairo  Singapore  London  New Dehli  Berlin  Montreal  \
# 0          23.5   11.1       24.7     5.4       15.2     6.6      -5.9
# 1          22.5   10.0       24.4     5.8       15.2     6.8      -8.6
# 2          21.5   10.0       24.2     5.9       15.2     7.0     -10.7
# 3          20.8   10.5       24.1     6.5       15.2     7.2     -12.0
# 4          20.1   10.9       24.1     6.9       15.0     7.3     -12.8
# 5          19.4   11.4       24.0     7.0       15.0     7.4     -13.5
# 6          18.9   11.9       24.2     7.4       14.2     7.0     -13.3
# 7          18.4   12.3       24.3     7.9       14.0     7.5     -14.4
# 8          17.9   12.8       25.5     8.5       13.5     7.7     -13.9
# 9          22.5   14.5       26.8     9.3       13.5     8.0     -12.8
# 10         16.7   16.1       28.0    10.8       13.4     7.6     -11.7
# 11         17.4   17.8       26.8    12.3       13.0     8.3     -10.6
# ...

# %%
db
# Out:
#                      Melbourne  Cairo  Singapore  London  New Dehli  Berlin  \
# Date
# 2021-01-01 00:00:00       23.5   11.1       24.7     5.4       15.2     6.6
# 2021-01-01 01:00:00       22.5   10.0       24.4     5.8       15.2     6.8
# 2021-01-01 02:00:00       21.5   10.0       24.2     5.9       15.2     7.0
# 2021-01-01 03:00:00       20.8   10.5       24.1     6.5       15.2     7.2
# 2021-01-01 04:00:00       20.1   10.9       24.1     6.9       15.0     7.3
# 2021-01-01 05:00:00       19.4   11.4       24.0     7.0       15.0     7.4
# 2021-01-01 06:00:00       18.9   11.9       24.2     7.4       14.2     7.0
# 2021-01-01 07:00:00       18.4   12.3       24.3     7.9       14.0     7.5
# 2021-01-01 08:00:00       17.9   12.8       25.5     8.5       13.5     7.7
# 2021-01-01 09:00:00       22.5   14.5       26.8     9.3       13.5     8.0
# 2021-01-01 10:00:00       16.7   16.1       28.0    10.8       13.4     7.6
# ...

# %%
db.columns
# Out:
# Index(['Melbourne', 'Cairo', 'Singapore', 'London', 'New Dehli', 'Berlin',
#        'Montreal', 'Tehran', 'Santiago'],
#       dtype='object')

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8760 entries, 2021-01-01 00:00:00 to 2021-12-31 23:00:00
# Data columns (total 9 columns):
# Melbourne    8760 non-null float64
# Cairo        8760 non-null float64
# Singapore    8760 non-null float64
# London       8760 non-null float64
# New Dehli    8760 non-null float64
# Berlin       8760 non-null float64
# Montreal     8760 non-null float64
# Tehran       8760 non-null float64
# Santiago     8760 non-null float64
# dtypes: float64(9)
# memory usage: 684.4 KB

# %% [markdown]
# # Resample

# %%
db.daily=db.resample("D").mean()
db.daily
# Out:
#             Melbourne      Cairo  Singapore     London  New Dehli    Berlin  \
# Date
# 2021-01-01  18.833333  14.629167  25.500000   9.837500  12.883333  7.187500
# 2021-01-02  16.650000  15.341667  26.475000   9.841667  11.529167  6.354167
# 2021-01-03  18.420833  15.158333  27.366667   6.304167  11.504167  6.358333
# 2021-01-04  19.795833  14.450000  26.987500   2.366667  11.850000  3.704167
# 2021-01-05  18.370833  13.662500  27.208333   1.829167  11.583333  1.741667
# 2021-01-06  15.508333  12.812500  26.987500   1.991667  11.766667  3.037500
# 2021-01-07  14.970833  14.025000  27.262500   0.516667  10.437500  2.850000
# 2021-01-08  17.525000  13.391667  27.200000  -0.079167   9.583333  2.333333
# 2021-01-09  19.341667  11.141667  27.541667   1.129167   9.725000  1.083333
# 2021-01-10  22.983333  11.179167  27.629167   3.341667   9.970833 -0.233333
# 2021-01-11  28.362500  11.854167  26.070833   1.437500  11.408333  1.429167
# ...

# %%
monthly=db.resample("M").mean()

# %%
monthly
# Out:
#             Melbourne      Cairo  Singapore     London  New Dehli     Berlin  \
# Date
# 2021-01-31  20.602016  13.434812  26.689247   5.993145  12.637097   1.873925
# 2021-02-28  20.730952  15.285417  27.230357   6.737946  16.837946   0.283929
# 2021-03-31  19.071909  18.273522  27.608737   8.374194  22.215457   5.417070
# 2021-07-31      11.14  28.02      28.11   18.08      31.13   18.35     19.64
#
#             Tehran  Santiago
# Date
# 2021-03-31    7.97     19.15
# 2021-05-31   19.06     12.85
# 2021-07-31   29.08      8.06

# %%
dbm.truncate(before="2021-3-31",after="2021-09-26").plot(figsize=(8,4))

# %% [markdown]
# # Dataframe and Dictionary

# %%
grades=pd.DataFrame({"math":[12,16,16,18,15],"physics":[15,14,13,19,20],"chemistary":[19,19,16,13,18]})
grades
# Out:
#    math  physics  chemistary
# 0    12       15          19
# 1    16       14          19
# 2    16       13          16
# 3    18       19          13
# 4    15       20          18

# %%
grades["classes"]=["a1","a2","a3","a4","a5"]

# %%
grades
# Out:
#    math  physics  chemistary classes
# 0    12       15          19      a1
# 1    16       14          19      a2
# 2    16       13          16      a3
# 3    18       19          13      a4
# 4    15       20          18      a5

# %%
grades=grades.set_index("classes")
grades
# Out:
#          math  physics  chemistary
# classes
# a1         12       15          19
# a2         16       14          19
# a3         16       13          16
# a4         18       19          13
# a5         15       20          18

# %% [markdown]
# # OPERATION

# %%
grades
# Out:
#          math  physics  chemistary
# classes
# a1         12       15          19
# a2         16       14          19
# a3         16       13          16
# a4         18       19          13
# a5         15       20          18

# %%
grades["physics"].unique()
# Out:
# array([15, 14, 13, 19, 20], dtype=int64)

# %%
grades["math"].nunique()   #to know howmany unique number we have in specific coloumn
# Out:
# 4

# %%
grades["math"].value_counts()   #number of each garde
# Out:
# 16    2
# 15    1
# 12    1
# 18    1
# Name: math, dtype: int64

# %%
grades["math"].value_counts()
# Out:
# 16    2
# 15    1
# 12    1
# 18    1
# Name: math, dtype: int64

# %%
grades["physics"].mean()
# Out:
# 16.2

# %%
grades["math"].sum()
# Out:
# 77

# %% [markdown]
# # apply function to one column

# %%
def fun(e):
    return e*1.2

# %%
grades["math"].apply(lambda e:e*1.2)    #apply faqat ru dataframe j mde nmishe azash vase list , ... estefade kard
# Out:
# classes
# a1    14.4
# a2    19.2
# a3    19.2
# a4    21.6
# a5    18.0
# Name: math, dtype: float64

# %% [markdown]
# # Sort values

# %%
grades
# Out:
#          math  physics  chemistary
# classes
# a1         12       15          19
# a2         16       14          19
# a3         16       13          16
# a4         18       19          13
# a5         15       20          18

# %%
grades["math"].sort_values()
# Out:
# classes
# a1    12
# a5    15
# a2    16
# a3    16
# a4    18
# Name: math, dtype: int64

# %%
grades.isnull()
# Out:
#           math  physics  chemistary
# classes
# a1       False    False       False
# a2       False    False       False
# a3       False    False       False
# a4       False    False       False
# a5       False    False       False

# %% [markdown]
# # Groupby

# %%
datac={"company":["dorf","asl","wintec","intel","wintec","intel"],
      "person":["sara","safa","emad","dorsa","ati","javid"],
      "sales":[1200,1500,800,970,1100,780]}

# %%
datac=pd.DataFrame(datac)
datac
# Out:
#   company person  sales
# 0    dorf   sara   1200
# 1     asl   safa   1500
# 2  wintec   emad    800
# 3   intel  dorsa    970
# 4  wintec    ati   1100
# 5   intel  javid    780

# %%
datac=datac.groupby("company").mean()
datac
# Out:
#          sales
# company
# asl       1500
# dorf      1200
# intel      875
# wintec     950

# %%
datac["sales"].sum()
# Out:
# 4525

# %%
datac["sales"].std()
# Out:
# 282.38198124762374

# %%
mantaqe={"school":["aban","dey","shahid","saman","dey","aban"],
        "student":["sara","sam","arya","gol","sahar","sima"],
        "math":[19,18,17,18,17,14],
         "physics":[12,16,13,18,15,19]}

# %%
mantaqe=pd.DataFrame(mantaqe)
mantaqe
# Out:
#    school student  math  physics
# 0    aban    sara    19       12
# 1     dey     sam    18       16
# 2  shahid    arya    17       13
# 3   saman     gol    18       18
# 4     dey   sahar    17       15
# 5    aban    sima    14       19

# %%
mantaq=mantaqe.groupby("school").mean()
mantaq
# Out:
#         math  physics
# school
# aban    16.5     15.5
# dey     17.5     15.5
# saman   18.0     18.0
# shahid  17.0     13.0

# %%
mantaq["math"].mean()
# Out:
# 17.25

# %%
mantaq.mean()
# Out:
# math       17.25
# physics    15.50
# dtype: float64

# %% [markdown]
# # Describe

# %%
mantaqe.groupby("school").describe()
# Out:
#         math                                                 physics        \
#        count  mean       std   min    25%   50%    75%   max   count  mean
# school
# aban     2.0  16.5  3.535534  14.0  15.25  16.5  17.75  19.0     2.0  15.5
# dey      2.0  17.5  0.707107  17.0  17.25  17.5  17.75  18.0     2.0  15.5
# saman    1.0  18.0       NaN  18.0  18.00  18.0  18.00  18.0     1.0  18.0
# shahid   1.0  17.0       NaN  17.0  17.00  17.0  17.00  17.0     1.0  13.0
#
#
#              std   min    25%   50%    75%   max
# school
# aban    4.949747  12.0  13.75  15.5  17.25  19.0
# dey     0.707107  15.0  15.25  15.5  15.75  16.0
# saman        NaN  18.0  18.00  18.0  18.00  18.0
# shahid       NaN  13.0  13.00  13.0  13.00  13.0

# %% [markdown]
# # Concatenate

# %%
## it is for merging two or three excel files

# %%
dif=pd.read_csv(r"E:\python\dataset\seesion2\DifSOL.csv",index_col="DATE",parse_dates=True)
dif
# Out:
#                      Diffuse
# DATE
# 2020-01-01 00:00:00        0
# 2020-01-01 01:00:00        0
# 2020-01-01 02:00:00        0
# 2020-01-01 03:00:00        0
# 2020-01-01 04:00:00        0
# 2020-01-01 05:00:00       32
# 2020-01-01 06:00:00       88
# 2020-01-01 07:00:00      213
# 2020-01-01 08:00:00      151
# 2020-01-01 09:00:00      241
# 2020-01-01 10:00:00      136
# 2020-01-01 11:00:00      113
# 2020-01-01 12:00:00      107
# 2020-01-01 13:00:00       90
# 2020-01-01 14:00:00       88
# 2020-01-01 15:00:00       58
# 2020-01-01 16:00:00       47
# 2020-01-01 17:00:00       37
# 2020-01-01 18:00:00       27
# 2020-01-01 19:00:00        0
# 2020-01-01 20:00:00        0
# 2020-01-01 21:00:00        0
# 2020-01-01 22:00:00        0
# 2020-01-01 23:00:00        0
# 2020-01-02 00:00:00        0
# 2020-01-02 01:00:00        0
# 2020-01-02 02:00:00        0
